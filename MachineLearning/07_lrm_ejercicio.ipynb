# %% [markdown]
# ### EJERCICIO: Regresión lineal con datos de ventas
#
# Supongamos que tienes un conjunto de datos que contiene información sobre las ventas de una tienda y la cantidad de dinero que se gastó en publicidad en diferentes medios (por ejemplo, televisión, radio y periódico).
#
# Tu tarea es desarrollar una función llamada regresion_ventas que tome estos datos como entrada y ajuste un modelo de regresión lineal para predecir las futuras ventas en función de la inversión en publicidad.
#
# ```python
# def regresion_ventas(datos):
#
# # Ejemplo de uso con datos reales
# data = {
#     'TV': [230.1, 44.5, 17.2, 151.5, 180.8],
#     'Radio': [37.8, 39.3, 45.9, 41.3, 10.8],
#     'Periodico': [69.2, 45.1, 69.3, 58.5, 58.4],
#     'Ventas': [22.1, 10.4, 9.3, 18.5, 12.9]
# }
# df = pd.DataFrame(data)
# modelo_regresion = regresion_ventas(df)
#
# # Estimaciones de ventas para nuevos datos de inversión en publicidad
# nuevos_datos = pd.DataFrame({'TV': [200, 60, 30], 'Radio': [40, 20, 10], 'Periodico': [50, 10, 5]})
# estimaciones_ventas = modelo_regresion.predict(nuevos_datos)
#
# print("Estimaciones de Ventas:")
# print(estimaciones_ventas)
#
# ```
# ```
# Resultado:
#
# Estimaciones de Ventas:
# [21.54261464  8.48121675  4.16961329]
# ```

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Parte OBLIGATORIA:

def regresion_ventas(datos):
    # Separar las variables independientes (TV, Radio, Periodico) y la variable dependiente (Ventas)
    X = datos[['TV', 'Radio', 'Periodico']]
    y = datos['Ventas']
    
    # Crear el modelo de regresión lineal
    modelo = LinearRegression()
    
    # Entrenar el modelo
    modelo.fit(X, y)
    
    return modelo

# Crear datos para entrenamiento
data = {
    'TV': [230.1, 44.5, 17.2, 151.5, 180.8],
    'Radio': [37.8, 39.3, 45.9, 41.3, 10.8],
    'Periodico': [69.2, 45.1, 69.3, 58.5, 58.4],
    'Ventas': [22.1, 10.4, 9.3, 18.5, 12.9]
}
df = pd.DataFrame(data)
modelo_regresion = regresion_ventas(df)

# Estimaciones de ventas para nuevos datos de inversión en publicidad
nuevos_datos = pd.DataFrame({'TV': [200, 60, 30], 'Radio': [40, 20, 10], 'Periodico': [50, 10, 5]})
estimaciones_ventas = modelo_regresion.predict(nuevos_datos)

print("Estimaciones de Ventas:")
print(estimaciones_ventas)
# Out:
# Estimaciones de Ventas:
# [21.54261464  8.48121675  4.16961329]

# %%
# EXTRA: Dividir los datos en entrenamiento y prueba (necesario para evaluación y visualización)

from sklearn.model_selection import train_test_split

X = df[['TV', 'Radio', 'Periodico']]
y = df['Ventas']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Predicciones en los datos de prueba
predicciones = modelo_regresion.predict(X_test)

# %%
# EXTRA: Evaluación del modelo

from sklearn.metrics import mean_absolute_error, mean_squared_error

mae = mean_absolute_error(y_test, predicciones)
mse = mean_squared_error(y_test, predicciones)
rmse = np.sqrt(mse)

print(f"MAE (Error Absoluto Medio): {mae}")
print(f"MSE (Error Cuadrático Medio): {mse}")
print(f"RMSE (Raíz del Error Cuadrático Medio): {rmse}")
# Out:
# MAE (Error Absoluto Medio): 0.12412921003331956
# MSE (Error Cuadrático Medio): 0.021490180585326795
# RMSE (Raíz del Error Cuadrático Medio): 0.14659529523598905

# %%
# EXTRA: Visualización de resultados

plt.figure(figsize=(8, 6))
plt.scatter(y_test, predicciones, alpha=0.7, color="blue", label ="Predicciones vs Reales")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color="red", linestyle="--", label="Línea Ideal")
plt.title("Predicciones vs Valores Reales")
plt.xlabel("Valores Reales")
plt.ylabel("Predicciones")
plt.grid(alpha=0.3)
plt.legend()
plt.show()

# %%
# EXTRA: Conclusión del modelo

# El modelo ajustado con los datos de publicidad muestra un rendimiento razonable. 
# Las predicciones generadas para las ventas están alineadas con los valores reales, lo que indica que existe una relación significativa 
# entre las variables independientes (TV, Radio, Periódico) y las ventas.

# Sin embargo, el gráfico muestra algunos errores entre las predicciones y los valores reales, lo que puede indicar que no todos los 
# factores que afectan las ventas están representados en las variables independientes.  

# En general, el modelo proporciona una base sólida para predecir ventas basándose en inversiones publicitarias, 
# pero podría beneficiarse de más datos o de un análisis más profundo para optimizar su rendimiento.
